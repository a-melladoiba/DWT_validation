# %%
import os
import pandas as pd
import numpy as np

# %%
save_path = 'C:/Users/alvar/Desktop/Discrete_validation/Statistical_generated_results'
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
mnf_sw_experiment = np.random.normal(51.4, 5.18, 100)

mnf_sw_paper = np.random.normal(53.07, 9.37, 100)

df = pd.DataFrame({
    'mnf_sw_experiment': mnf_sw_experiment,
    'mnf_sw_paper': mnf_sw_paper
})

df.to_csv(save_path + '/mnf_sw.csv', index=False)

mnf_st_experiment = np.random.normal(53.2, 6.25, 100)

mnf_st_paper = np.random.normal(54.17, 7.72, 100)

df = pd.DataFrame({
    'mnf_st_experiment': mnf_st_experiment,
    'mnf_st_paper': mnf_st_paper
})

df.to_csv(save_path + '/mnf_st.csv', index=False)

mdf_sw_experiment = np.random.normal(49.9, 6.82, 100)

mdf_sw_paper = np.random.normal(45.43, 11.64, 100)

df = pd.DataFrame({
    'mdf_sw_experiment': mdf_sw_experiment,
    'mdf_sw_paper': mdf_sw_paper
})

df.to_csv(save_path + '/mdf_sw.csv', index=False)

mdf_st_experiment = np.random.normal(51.6, 8.19, 100)

mdf_st_paper = np.random.normal(48.48, 13.51, 100)

df = pd.DataFrame({
    'mdf_st_experiment': mdf_st_experiment,
    'mdf_st_paper': mdf_st_paper
})

df.to_csv(save_path + '/mdf_st.csv', index=False)
